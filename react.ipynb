# %%
pip install langchainhub -q
# Out:
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
from dotenv import load_dotenv, find_dotenv

load_dotenv(find_dotenv(), override=True)
# Out:
# True

# %%
from langchain_classic.prompts import PromptTemplate
from langchain_classic import hub
from langchain_classic.agents import (
    Tool,
    AgentExecutor,
    initialize_agent,
    create_react_agent,
)
from langchain_classic.tools import DuckDuckGoSearchRun, WikipediaQueryRun
from langchain_classic.utilities import WikipediaAPIWrapper
from langchain_experimental.utilities import PythonREPL
from langchain_openai import ChatOpenAI
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[7], line 11
#       9 from langchain_classic.tools import DuckDuckGoSearchRun, WikipediaQueryRun
#      10 from langchain_classic.utilities import WikipediaAPIWrapper
# ---> 11 from langchain_experimental.utilities import PythonREPL
#      12 from langchain_openai import ChatOpenAI
#
# ModuleNotFoundError: No module named 'langchain_experimental'
