# %%
pip install -q duckduckgo-search
# Out:
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
from langchain_classic.tools import DuckDuckGoSearchRun

search = DuckDuckGoSearchRun()
output = search.invoke("Where was freddie Mercury Born")
print(output)
# Out:
# Freddie tornou-se conhecido pelo seu poderoso tom de voz e pelos seus desempenhos enérgicos que envolviam uma interação com a plateia, tendo sido também considerado como um dos … 2 days ago · Freddie Mercury — Foto: Getty Images A música 'Bohemian Rhapsody', um dos maiores sucessos do Queen, foi lançada em 31 de outubro de 1975 e vendeu mais de 6 milhões … Descubra os detalhes dos últimos dias e a morte de Freddie Mercury, vocalista do Queen. Saiba como ele enfrentou o HIV e seu impacto na música e na conscientização sobre a doença. Apesar do seu talento fora do comum, Freddie funcionava ainda melhor quando estava acompanhado dos seus companheiros no Queen. Pra quem viu o filme Bohemian Rhapsody, isso … Sep 8, 2019 · A experiência e o diploma tiveram um grande peso quando se trata do logo do Queen, conhecido como Queen Crest e desenhado pelo próprio Freddie Mercury. E os símbolos …

# %%
search.name
# Out:
# 'duckduckgo_search'

# %%
search.description
# Out:
# 'A wrapper around DuckDuckGo Search. Useful for when you need to answer questions about current events. Input should be a search query.'

# %%
from langchain_classic.tools import DuckDuckGoSearchResults

search = DuckDuckGoSearchResults()
output = search.run("Freedie Mercurcy and the queen")
print(output)
# Out:
# snippet: Every Queen show came back to Freddie Mercury, but the frontman thought that this band member started to make him nervous from a musical standpoint., title: The one member of Queen that "worried" Freddie Mercury, link: https://faroutmagazine.co.uk/one-member-of-queen-that-worried-freddie-mercury/, snippet: Queen legend Freddie Mercury immortalised on new collection of Royal Mint coins Singer's sister, Kashmira Bulsara, said that striking the first coin was an 'emotional and proud moment' for her, title: Queen legend Freddie Mercury immortalised on new collection of Royal ..., link: https://www.independent.co.uk/arts-entertainment/music/news/freddie-mercury-royal-mint-coins-b2866518.html, snippet: The Freddie Mercury Tribute Concert would be one of John Deacon's final times performing live with Queen , but it is clear the private bassist felt positively about Queen continuing to perform following Freddie's death. Echoing one of Freddie's last songs, he told crowds at the start of the show: " The show must go on." Final album One year on from successfully producing the ..., title: How Queen continue to honour Freddie Mercury after his death, link: https://www.smoothradio.com/artists/queen/freddie-mercury-legacy/, snippet: Tribute bands like Almost Queen are a testament to Queen's legacy. The crowds that go to see Almost Queen are a testament to how Queen music continues to be passed down between generations. The recreation of Freddie Mercury's fashion, relishing in his energetic and engaging performances and amazement at his unique voice are part of the ..., title: The enduring image of Freddie Mercury and Queen, link: https://dailycollegian.com/2024/12/the-enduring-image-of-freddie-mercury-and-queen/

# %%
from langchain_community.utilities import DuckDuckGoSearchAPIWrapper

wrapper = DuckDuckGoSearchAPIWrapper(
    region="pt-br", max_results=3, safesearch="moderate"
)
search = DuckDuckGoSearchResults(api_wrapper=wrapper, source="news")
output = search.run("São paulo")
print(output)
# Out:
# snippet: São Paulo (distaget: [sɐ̃w̃ 'paw.lu]) (Sant Paol), eo kêr vrasañ Brazil, ha kêr-benn stad São Paulo, e gevred ar vro. Unan eus kêrioù brasañ ar bed eo, gant 20 milion a dud enni., title: São Paulo (kêr), link: https://br.wikipedia.org/wiki/São_Paulo_(kêr), snippet: O condomínio é bem equipado com diversas instalações e fica localizado em Rua Gomes de Carvalho no bairro Vila Olímpia em São Paulo ., title: Apartamento com 1 quarto para alugar em Vila Olímpia, São Paulo por..., link: https://www.quintoandar.com.br/imovel/893374266/alugar/apartamento-1-quarto-vila-olimpia-sao-paulo?from_route="search_results"&house_tags=exclusivity&house_tags=rentOnTermination&search_id="5b06d085-2559-4743-b838-026b0f681c38"&search_rank={"sortMode":"relevance","searchMode":"list","resultsOrigin":"search","rank":6,"personalization":false}, snippet: Desfalques do São Paulo para o Majestoso. A baixa mais recente do Tricolor Paulista é o zagueiro Arboleda . Titular absoluto da equipe..., title: A provável escalação do São Paulo contra o Corinthians pelo Brasileirão, link: https://www.90min.com/pt-br/provavel-escalacao-sao-paulo-contra-corinthians-brasileirao-20-11-2025, snippet: But São Paulo , Brazil's biggest and most modern city, also has plenty of flair.Unlike the traffic nightmare during the week, downtown São Paulo can feel like a ghost town on weekends., title: 36 Hours in São Paulo - The New York Times, link: https://www.nytimes.com/2007/10/14/travel/14hours.html

# %%
import re

pattern = r"snippet: (.*?), title: (.*?), link:(.*?)\],"
matches = re.findall(pattern, output, re.DOTALL)

for snippet, title, link in matches:
    print(f"Snippet: {snippet}\nTitle: {title}\nLink: {link}\n")
    print("-" * 50)

# %%
pip install -q wikipedia
# Out:
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
from langchain_community.tools import WikipediaQueryRun
from langchain_community.utilities import WikipediaAPIWrapper

api_wrapper = WikipediaAPIWrapper(top_k_results=1, doc_content_chars_max=5000)
wiki = WikipediaQueryRun(api_wrapper=api_wrapper)
wiki.invoke({"query": "llamaindex"})
# Out:
# 'Page: Vector database\nSummary: A vector database, vector store or vector search engine is a database that uses the vector space model to store vectors (fixed-length lists of numbers) along with other data items. Vector databases typically implement one or more approximate nearest neighbor algorithms, so that one can search the database with a query vector to retrieve the closest matching database records.\nVectors are mathematical representations of data in a high-dimensional space. In this space, each dimension corresponds to a feature of the data, with the number of dimensions ranging from a few hundred to tens of thousands, depending on the complexity of the data being represented. A vector\'s position in this space represents its characteristics. Words, phrases, or entire documents, as well as images, audio, and other types of data, can all be vectorized.\nThese feature vectors may be computed from the raw data using machine learning methods such as feature extraction algorithms, word embeddings or deep learning networks. The goal is that semantically similar data items receive feature vectors close to each other.\nVector databases can be used for similarity search, semantic search, multi-modal search, recommendations engines, large language models (LLMs), object detection,  etc.\nVector databases are also often used to implement retrieval-augmented generation (RAG), a method to improve domain-specific responses of large language models. The retrieval component of a RAG can be any search system, but is most often implemented as a vector database. Text documents describing the domain of interest are collected, and for each document or document section, a feature vector (known as an "embedding") is computed, typically using a deep learning network, and stored in a vector database. Given a user prompt, the feature vector of the prompt is computed, and the database is queried to retrieve the most relevant documents. These are then automatically added into the context window of the large language model, and the large language model proceeds to create a response to the prompt given this context.'

# %%
wiki.invoke("Google Gemini")
# Out:
# "Page: Google Gemini\nSummary: Gemini (formerly Bard), also known as Google Gemini, is a generative artificial intelligence chatbot and virtual assistant developed by Google. Based on the large language model (LLM) of the same name, it was launched in March 2023 in response to the rise of OpenAI's ChatGPT.\n\n"
