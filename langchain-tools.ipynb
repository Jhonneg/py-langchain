# %%
pip install -q duckduckgo-search
# Out:
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
from langchain_classic.tools import DuckDuckGoSearchRun

search = DuckDuckGoSearchRun()
output = search.invoke("Where was freddie Mercury Born")
print(output)
# Out:
# Freddie Mercury ( born September 5, 1946, Stone Town, Zanzibar [now in Tanzania]—died November 24, 1991, Kensington, London, England) was a British rock singer and songwriter whose flamboyant showmanship and powerfully agile vocals, most famously for the band Queen, made him one of rock's most dynamic front men. Freddie Mercury , a talented singer-songwriter, was the frontman of Queen. Discover details about his age, marriage, and relationships. Freddie Mercury was born Farrokh Bulsara on September 5, 1946, in Zanzibar, an archipelago in the Indian Ocean just off the coast of Tanzania. Freddie Mercury , born Farrokh Bulsara on September 5, 1946, in Stone Town, Zanzibar (now part of Tanzania), was a British singer, songwriter, and record producer. Renowned as the flamboyant frontman of the rock band Queen, Mercury's powerful vocals and dynamic stage presence cemented his status as one of rock music's most iconic figures. FAQs Where was Freddie Mercury born ? Freddie Mercury was born o
# ...

# %%
search.name
# Out:
# 'duckduckgo_search'

# %%
search.description
# Out:
# 'A wrapper around DuckDuckGo Search. Useful for when you need to answer questions about current events. Input should be a search query.'

# %%
from langchain_classic.tools import DuckDuckGoSearchResults

search = DuckDuckGoSearchResults()
output = search.run("Freedie Mercurcy and the queen")
print(output)
# Out:
# snippet: Your Account Your Orders Shipping Rates & Policies Amazon Prime Returns & Replacements Manage Your Content and Devices Recalls and Product Safety Alerts, title: Amazon.com: Homepage, link: https://www.amazon.com/stores/Homepage/page/1C97BE5A-7354-49E3-828D-1A49B8513E5E, snippet: Can I share my Prime benefits with other household members? Prime members can share certain benefits with another adult in their Amazon Household. Prime for Young Adults does not …, title: Amazon.com: Amazon Prime, link: https://www.amazon.com/amazonprime, snippet: Amazon Fire TV Stick HD (newest model), free and live TV, Alexa Voice Remote, smart home controls, HD streaming 10K+ bought in past month Limited time deal Add to cart, title: Amazon.com:, link: https://www.amazon.com/stores/USA/node/17376892011, snippet: By continuing, you agree to Amazon's Conditions of Use and Privacy Notice. Need help? New to Amazon?, title: Amazon Sign-In, link: https://amc.amazon.com/
