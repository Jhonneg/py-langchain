# %%
pip install -q duckduckgo-search
# Out:
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
from langchain_classic.tools import DuckDuckGoSearchRun

search = DuckDuckGoSearchRun()
output = search.invoke("Where was freddie Mercury Born")
print(output)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[26], line 4
#       1 from langchain_classic.tools import DuckDuckGoSearchRun
#       3 search = DuckDuckGoSearchRun()
# ----> 4 output = search.invoke("Where was freddie Mercury Born")
#       5 print(output)
#
# File ~/Work/py-langchain/venv/lib/python3.13/site-packages/langchain_core/tools/base.py:610, in BaseTool.invoke(self, input, config, **kwargs)
#     602 @override
#     603 def invoke(
#     604     self,
#    (...)    607     **kwargs: Any,
#     608 ) -> Any:
#     609     tool_input, kwargs = _prep_run_args(input, config, **kwargs)
# --> 610     return self.run(tool_input, **kwargs)
#
# File ~/Work/py-langchain/venv/lib/python3.13/site-packages/langchain_core/tools/base.py:826, in BaseTool.run(self, tool_input, verbose, start_color, color, callbacks, tags, metadata, run_name, run_id, config, tool_call_id, **kwargs)
#     788 def run(
#     789     self,
#     790     tool_input: Union[str, dict[str, Any]],
#    (...)    802     **kwargs: Any,
#     803 ) -> Any:
#     804     """Run the tool.
#     805
#     806     Args:
#    (...)    824         ToolException: If an error occurs during tool execution.
#     825     """
# --> 826     callback_manager = CallbackManager.configure(
#     827         callbacks,
#     828         self.callbacks,
#     829         self.verbose or bool(verbose),
#     830         tags,
#     831         self.tags,
#     832         metadata,
#     833         self.metadata,
#     834     )
#     836     run_manager = callback_manager.on_tool_start(
#     837         {"name": self.name, "description": self.description},
#     838         tool_input if isinstance(tool_input, str) else str(tool_input),
#    (...)    847         **kwargs,
#     848     )
#     850     content = None
#
# File ~/Work/py-langchain/venv/lib/python3.13/site-packages/langchain_core/callbacks/manager.py:1655, in CallbackManager.configure(cls, inheritable_callbacks, local_callbacks, verbose, inheritable_tags, local_tags, inheritable_metadata, local_metadata)
#    1623 @classmethod
#    1624 def configure(
#    1625     cls,
#    (...)   1632     local_metadata: Optional[dict[str, Any]] = None,
#    1633 ) -> CallbackManager:
#    1634     """Configure the callback manager.
#    1635
#    1636     Args:
#    (...)   1653
#    1654     """
# -> 1655     return _configure(
#    1656         cls,
#    1657         inheritable_callbacks,
#    1658         local_callbacks,
#    1659         inheritable_tags,
#    1660         local_tags,
#    1661         inheritable_metadata,
#    1662         local_metadata,
#    1663         verbose=verbose,
#    1664     )
#
# File ~/Work/py-langchain/venv/lib/python3.13/site-packages/langchain_core/callbacks/manager.py:2457, in _configure(callback_manager_cls, inheritable_callbacks, local_callbacks, inheritable_tags, local_tags, inheritable_metadata, local_metadata, verbose)
#    2454     raise RuntimeError(msg)
#    2456 tracer_project = _get_tracer_project()
# -> 2457 debug = _get_debug()
#    2458 if verbose or debug or tracing_v2_enabled_:
#    2459     if verbose and not any(
#    2460         isinstance(handler, StdOutCallbackHandler)
#    2461         for handler in callback_manager.handlers
#    2462     ):
#
# File ~/Work/py-langchain/venv/lib/python3.13/site-packages/langchain_core/callbacks/manager.py:59, in _get_debug()
#      58 def _get_debug() -> bool:
# ---> 59     return get_debug()
#
# File ~/Work/py-langchain/venv/lib/python3.13/site-packages/langchain_core/globals.py:148, in get_debug()
#     132         warnings.filterwarnings(
#     133             "ignore",
#     134             message="Importing debug from langchain root module "
#     135             "is no longer supported",
#     136         )
#     137         # N.B.: This is a workaround for an unfortunate quirk of Python's
#     138         #       module-level `__getattr__()` implementation:
#     139         # https://github.com/langchain-ai/langchain/pull/11311#issuecomment-1743780004
#    (...)    146         # to using `set_debug()` yet. Those users are getting deprecation warnings
#     147         # directing them to use `set_debug()` when they import `langchain.debug`.
# --> 148         old_debug = langchain.debug
#     149 else:
#     150     old_debug = False
#
# AttributeError: module 'langchain' has no attribute 'debug'
