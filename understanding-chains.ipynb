# %% [markdown]
# # Understanding Chains

# %%
from dotenv import load_dotenv, find_dotenv

load_dotenv(find_dotenv(), override=True)
# Out:
# True

# %%
from langchain_openai import ChatOpenAI
from langchain_classic.prompts import ChatPromptTemplate, HumanMessagePromptTemplate
from langchain_core.messages import SystemMessage

llm = ChatOpenAI(model="gpt-4o-mini")
chat_template = ChatPromptTemplate.from_messages(
    [
        SystemMessage(content="You are a visionary scientist from the future."),
        HumanMessagePromptTemplate.from_template(
            "Describe how humans will explore {location} in the year {year}, using advanced technologies"
        ),
    ]
)

chain = chat_template | llm
output = chain.invoke({"location": "The oceans of europa", "year": "2150"})
print(output.content)
# Out:
# By the year 2150, human exploration of the oceans of Europa, one of Jupiter's moons, has become a cornerstone of deep-space exploration and astrobiology. Emerging technologies have transformed this endeavor into a multifaceted mission, combining robotics, artificial intelligence, and advanced materials.
#
# 1. **Robotic Submersibles**: Leading the exploration efforts are autonomous robotic submersibles, equipped with advanced AI. These submarines, designed to withstand extreme temperatures and pressures, can navigate Europa’s icy crust and plunge into its subsurface ocean. They feature sonar mapping technologies, allowing for high-resolution 3D imaging of the ocean floor and detecting potential bio-signatures.
#
# 2. **Cryogenic Launch Systems**: Launching missions to Europa is feasible thanks to sophisticated cryogenic launch systems. These systems leverage ion propulsion and magnetic levitation technologies to transport payloads from Earth to space more efficiently. Specialized robotic payloads capable of self-repair during long journeys ensure missions can be sustained over years.
#
# 3. **Ice Penetration Technology**: Exploration begins with the deployment of ice-penetrating drones. These drones are equipped with thermal and sonic drilling technologies that can melt or mechanically penetrate the ice crust, creating access points to the ocean below. Once a suitable access point is established, submersibles can be deployed directly into the ocean.
#
# 4. **In-situ Resource Utilization (ISRU)**: To sustain long-term operations on Europa, there are advancements in ISRU technologies. These systems can harvest water ice, extract necessary gases, and generate energy through compact fusion reactors or advanced solar panels, ensuring that missions can remain active without resupply from Earth.
#
# 5. **Bio-Detection Systems**: The scientific goal of exploring Europa’s oceans is the search for signs of life. State-of-the-art bio-detection systems integrated into the robotic submersibles are capable of analyzing chemical compositions and identifying organic molecules. These systems utilize miniaturized spectrometers and chromatographs to assess the ocean’s chemistry and search for potential biosignatures.
#
# 6. **Communication Networks**: A robust communication network using quantum entanglement technology allows near-instant transmission of data between Europa's surface and Earth. This advances our understanding of the ocean dynamics and promotes real-time monitoring of missions, providing scientists with immediate insights and facilitating quick decision-making.
#
# 7. **Collaborative AI Platforms**: Central to mission operations is the use of collaborative AI platforms that synthesize data from numerous missions, enabling scientists to visualize findings and develop hypotheses about the potential for life in Europa's oceans. These platforms can also automate routine tasks for the submersibles while allowing human crews to focus on complex problem-solving.
#
# 8. **Human Habitats**: As exploration progresses, temporary human habitats, known as Orbital Habitats for Underwater Research (OHUR), are established on the surface of Europa or in its icy crust. These habitats incorporate advanced life-support systems that can recycle air and water, providing a base for human researchers who can conduct experiments directly on site.
#
# 9. **Interdisciplinary Collaboration**: Explorations in 2150 are characterized by the collaboration of scientists, engineers, and even artists to interpret the findings of Europa's oceans. The fusion of astrophysics, marine biology, and planetary science leads to a holistic understanding of the moon's ecosystems and their implications for the origin of life.
#
# Through these advanced technologies and logical methodologies, the missions to explore the oceans of Europa by 2150 become not just a quest for knowledge but also a testament to human ingenuity and the relentless drive to uncover the mysteries of the cosmos.
